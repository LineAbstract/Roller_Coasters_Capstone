# %% [markdown]
# ## Data Munging

# %% [markdown]
# #### Step 1: Imports and reading the data:

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pylab as plt

# %% [markdown]
# ##### Reading Data

# %%
df_coaster_metrics = pd.read_csv('../d_coaster_metrics_original.csv', index_col= 'Coaster_ID')
df_park_locations = pd.read_csv('../d_park_locations_original.csv', index_col= 'Park_ID')
df_wood_coasters = pd.read_csv('../d_wood_coasters_original.csv')
df_steel_coasters = pd.read_csv('../d_steel_coasters_original.csv')

# %% [markdown]
# #### Step 2: Understanding the Data:
# - shape
# - head/tail
# - columns
# - dtypes
# - info/describe

# %% [markdown]
# ##### Coaster Metrics:

# %%
def print_shape(dataset):
    print(f'Dataset shape: {dataset.shape}')
    print(f'No. of rows: {dataset.shape[0]}')
    print(f'No. of columns: {dataset.shape[1]}')

print_shape(df_coaster_metrics)
# Out:
# Dataset shape: (272, 10)
# No. of rows: 272
# No. of columns: 10

# %%
df_coaster_metrics.head(10)
# Out:
#                         Name material_type seating_type  speed  height  \
# Coaster_ID
# 1                  Afterburn         Steel     Inverted  100.0    34.0
# 2                 Alpengeist         Steel     Inverted  108.0    60.0
# 3           American Thunder        Wooden     Sit Down   77.0    25.0
# 4                 Apocalypse        Wooden     Sit Down   89.0    31.0
# 5           Apollo's Chariot         Steel     Sit Down  118.0    52.0
# 6                       Aska        Wooden     Sit Down   80.0    30.0
# 7                  Avalanche        Wooden     Sit Down    NaN    27.0
# 8                     Balder        Wooden     Sit Down   90.0    36.0
# 9                    Banshee         Steel     Inverted  110.0    51.0
# 10                     Beast        Wooden     Sit Down  104.0    34.0
#
#             length  num_inversions  manufacturer                        Park  \
# Coaster_ID
# 1            900.0             6.0           B&M                   Carowinds
# 2              NaN             6.0           B&M  Busch Gardens Williamsburg
# 3            827.0             0.0           GCI         Six Flags St. Louis
# 4            869.0             0.0           GCI    Six Flags Magic Mountain
# 5           1488.0             0.0           B&M  Busch Gardens Williamsburg
# 6           1081.0             0.0       Intamin              Nara Dreamland
# 7            725.0             0.0           S&S                Timber Falls
# 8           1070.0             0.0       Intamin                    Liseberg
# 9           1260.0             7.0           B&M                Kings Island
# 10          2243.0             0.0  Charlie Dinn                Kings Island
#
#                                status
# Coaster_ID
# 1                    status.operating
# 2                    status.operating
# 3                    status.operating
# 4           status.closed.temporarily
# 5                    status.operating
# 6            status.closed.definitely
# 7            status.closed.definitely
# 8                    status.operating
# 9                    status.operating
# 10                   status.operating

# %%
df_coaster_metrics.columns
# Out:
# Index(['Name', 'material_type', 'seating_type', 'speed', 'height', 'length',
#        'num_inversions', 'manufacturer', 'Park', 'status'],
#       dtype='object')

# %%
df_coaster_metrics.dtypes
# Out:
# Name               object
# material_type      object
# seating_type       object
# speed             float64
# height            float64
# length            float64
# num_inversions    float64
# manufacturer       object
# Park               object
# status             object
# dtype: object

# %%
df_coaster_metrics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 272 entries, 1 to 272
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            272 non-null    object
#  1   material_type   272 non-null    object
#  2   seating_type    272 non-null    object
#  3   speed           223 non-null    float64
#  4   height          240 non-null    float64
#  5   length          233 non-null    float64
#  6   num_inversions  261 non-null    float64
#  7   manufacturer    272 non-null    object
#  8   Park            272 non-null    object
#  9   status          272 non-null    object
# dtypes: float64(4), object(6)
# memory usage: 23.4+ KB

# %%
df_coaster_metrics.describe()
# Out:
#             speed      height       length  num_inversions
# count  223.000000  240.000000   233.000000      261.000000
# mean    94.174888   39.292167  1066.684378        1.122605
# std     25.295032   20.540048   402.945595        2.040057
# min     39.000000    5.000000   233.000000        0.000000
# 25%     80.000000   26.000000   832.000000        0.000000
# 50%     92.000000   34.000000  1024.000000        0.000000
# 75%    111.000000   51.000000  1283.000000        2.000000
# max    206.000000  139.000000  2479.000000        9.000000

# %% [markdown]
# ##### Park Locations:

# %%
print_shape(df_park_locations)
# Out:
# Dataset shape: (91, 5)
# No. of rows: 91
# No. of columns: 5

# %%
df_park_locations.head(10)
# Out:
#                                Park          City             State  \
# Park_ID
# 1                       Cedar Point      Sandusky              Ohio
# 2                      Kings Island         Mason              Ohio
# 3                     Holiday World   Santa Claus           Indiana
# 4         Six Flags Great Adventure       Jackson        New Jersey
# 5         Knoebels Amusement Resort      Elysburg      Pennsylvania
# 6        Busch Gardens Williamsburg  Williamsburg          Virginia
# 7                         Kennywood  West Mifflin      Pennsylvania
# 8                          Liseberg    Gothenburg  Västra Götalands
# 9                         Carowinds     Charlotte    North Carolina
# 10                        Dollywood  Pigeon Forge         Tennessee
#
#                Country Zip_Code
# Park_ID
# 1        United States    44870
# 2        United States    45040
# 3        United States    47579
# 4        United States    08527
# 5        United States    17824
# 6        United States    23185
# 7        United States    15122
# 8               Sweden   402 22
# 9        United States    28273
# 10       United States    37863

# %%
df_park_locations.columns
# Out:
# Index(['Park', 'City', 'State', 'Country', 'Zip_Code'], dtype='object')

# %%
df_park_locations.dtypes
# Out:
# Park        object
# City        object
# State       object
# Country     object
# Zip_Code    object
# dtype: object

# %%
df_park_locations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 91 entries, 1 to 91
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Park      91 non-null     object
#  1   City      91 non-null     object
#  2   State     91 non-null     object
#  3   Country   91 non-null     object
#  4   Zip_Code  91 non-null     object
# dtypes: object(5)
# memory usage: 4.3+ KB

# %%
df_park_locations.describe()
# Out:
#                Park     City       State        Country Zip_Code
# count            91       91          91             91       91
# unique           91       85          56             19       88
# top     Cedar Point  Orlando  California  United States    92802
# freq              1        3           7             56        2

# %% [markdown]
# ##### Wood Coasters:

# %%
print_shape(df_wood_coasters)
# Out:
# Dataset shape: (605, 8)
# No. of rows: 605
# No. of columns: 8

# %%
df_wood_coasters.head(10)
# Out:
#    Rank Year_of_Rank Award_Category             Name  \
# 0     1         2022         Wooden          Phoenix
# 1     2         2022         Wooden           Voyage
# 2     3         2022         Wooden          El Toro
# 3     4         2022         Wooden     Boulder Dash
# 4     5         2022         Wooden            Beast
# 5     6         2022         Wooden   Mystic Timbers
# 6     7         2022         Wooden  Ravine Flyer II
# 7     8         2022         Wooden       GhostRider
# 8     9         2022         Wooden       Outlaw Run
# 9    10         2022         Wooden      Thunderhead
#
#                         Park                 Location               Supplier  \
# 0  Knoebels Amusement Resort   Elysburg, Pennsylvania        Dinn-PTC/Shmeck
# 1              Holiday World     Santa Claus, Indiana      The Gravity Group
# 2  Six Flags Great Adventure      Jackson, New Jersey                Intamin
# 3             Lake Compounce     Bristol, Connecticut   Custom Coasters Int.
# 4               Kings Island              Mason, Ohio                   KECO
# 5               Kings Island              Mason, Ohio    Great Coasters Int.
# 6                  Waldameer       Erie, Pennsylvania      The Gravity Group
# 7         Knott's Berry Farm   Buena Park, California   Custom Coasters/GCII
# 8         Silver Dollar City        Branson, Missouri  Rocky Mountain Const.
# 9                  Dollywood  Pigeon Forge, Tennessee    Great Coasters Int.
#
#   Year_Built
# 0       1985
# 1       2006
# 2       2006
# 3       2000
# 4       1979
# 5       2017
# 6       2008
# 7       1998
# 8       2013
# 9       2004

# %%
df_wood_coasters.columns
# Out:
# Index(['Rank', 'Year_of_Rank', 'Award_Category', 'Name', 'Park', 'Location',
#        'Supplier', 'Year_Built'],
#       dtype='object')

# %%
df_wood_coasters.dtypes
# Out:
# Rank               int64
# Year_of_Rank      object
# Award_Category    object
# Name              object
# Park              object
# Location          object
# Supplier          object
# Year_Built        object
# dtype: object

# %%
df_wood_coasters.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 605 entries, 0 to 604
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rank            605 non-null    int64
#  1   Year_of_Rank    605 non-null    object
#  2   Award_Category  605 non-null    object
#  3   Name            605 non-null    object
#  4   Park            605 non-null    object
#  5   Location        605 non-null    object
#  6   Supplier        605 non-null    object
#  7   Year_Built      605 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 37.9+ KB

# %%
df_wood_coasters.describe()
# Out:
#              Rank
# count  605.000000
# mean    25.433058
# std     14.430499
# min      1.000000
# 25%     13.000000
# 50%     25.000000
# 75%     38.000000
# max     50.000000

# %% [markdown]
# ##### Steel Coasters:

# %%
print_shape(df_steel_coasters)
# Out:
# Dataset shape: (605, 8)
# No. of rows: 605
# No. of columns: 8

# %%
df_steel_coasters.head(10)
# Out:
#    Rank Year_of_Rank Award_Category                          Name  \
# 0     1         2022          Steel                      Fury 325
# 1     2         2022          Steel               Steel Vengeance
# 2     3         2022          Steel              Millennium Force
# 3     4         2022          Steel                    Iron Gwazi
# 4     5         2022          Steel  Jurassic World VelociCoaster
# 5     6         2022          Steel            Expedition GeForce
# 6     7         2022          Steel             Superman The Ride
# 7     8         2022          Steel              Apollo's Chariot
# 8     9         2022          Steel               Intimidator 305
# 9    10         2022          Steel                      Maverick
#
#                                Park                   Location  \
# 0                         Carowinds  Charlotte, North Carolina
# 1                       Cedar Point             Sandusky, Ohio
# 2                       Cedar Point             Sandusky, Ohio
# 3               Busch Gardens Tampa             Tampa, Florida
# 4  Universal's Islands of Adventure           Orlando, Florida
# 5                      Holiday Park          Hassloch, Germany
# 6             Six Flags New England      Agawam, Massachusetts
# 7        Busch Gardens Williamsburg     Williamsburg, Virginia
# 8                    Kings Dominion          Doswell, Virginia
# 9                       Cedar Point             Sandusky, Ohio
#
#                 Supplier Year_Built
# 0                    B&M       2015
# 1  Rocky Mountain Const.       2018
# 2                Intamin       2000
# 3  Rocky Mountain Const.       2022
# 4                Intamin       2021
# 5                Intamin       2001
# 6                Intamin       2000
# 7                    B&M       1999
# 8                Intamin       2010
# 9                Intamin       2007

# %%
df_steel_coasters.columns
# Out:
# Index(['Rank', 'Year_of_Rank', 'Award_Category', 'Name', 'Park', 'Location',
#        'Supplier', 'Year_Built'],
#       dtype='object')

# %%
df_steel_coasters.dtypes
# Out:
# Rank               int64
# Year_of_Rank      object
# Award_Category    object
# Name              object
# Park              object
# Location          object
# Supplier          object
# Year_Built        object
# dtype: object

# %%
df_steel_coasters.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 605 entries, 0 to 604
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rank            605 non-null    int64
#  1   Year_of_Rank    605 non-null    object
#  2   Award_Category  605 non-null    object
#  3   Name            605 non-null    object
#  4   Park            605 non-null    object
#  5   Location        605 non-null    object
#  6   Supplier        605 non-null    object
#  7   Year_Built      605 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 37.9+ KB

# %%
df_steel_coasters.describe()
# Out:
#              Rank
# count  605.000000
# mean    25.462810
# std     14.378885
# min      1.000000
# 25%     13.000000
# 50%     26.000000
# 75%     38.000000
# max     50.000000

# %% [markdown]
# #### Step 3: Data Prep

# %% [markdown]
# ##### Renaming, reindexing, missing values, duplicate values, merging/joining tables into one

# %% [markdown]
# ##### Coaster Metrics:

# %%
df_coaster_metrics = df_coaster_metrics.rename(columns= {
                                                    'Name': 'coaster_name',
                                                    'Park': 'park_name' # link this w/ df_park_locations
                                                    })

df_coaster_metrics = df_coaster_metrics.reindex(columns=[
                                                    'coaster_name',
                                                    'status',
                                                    'speed',
                                                    'height',
                                                    'length',
                                                    'num_inversions',
                                                    'material_type',
                                                    'manufacturer',
                                                    'seating_type',
                                                    'park_name'
                                                    ])

df_coaster_metrics.info()
# df_coaster_metrics.sort_values(by= 'coaster_name')

# df_coaster_metrics.duplicated(subset= ['coaster_name']).sum()

# duplicates = df_coaster_metrics[df_coaster_metrics['coaster_name'].duplicated()]
# print(duplicates)

# df_coaster_metrics.isna()
# df_coaster_metrics.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 272 entries, 1 to 272
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   coaster_name    272 non-null    object
#  1   status          272 non-null    object
#  2   speed           223 non-null    float64
#  3   height          240 non-null    float64
#  4   length          233 non-null    float64
#  5   num_inversions  261 non-null    float64
#  6   material_type   272 non-null    object
#  7   manufacturer    272 non-null    object
#  8   seating_type    272 non-null    object
#  9   park_name       272 non-null    object
# dtypes: float64(4), object(6)
# memory usage: 23.4+ KB

# %% [markdown]
# ##### Park Locations:

# %%
df_park_locations = df_park_locations.rename(columns= {
                                                    'Park': 'park_name', # link this w/ df_coaster_metrics
                                                    'City': 'city',
                                                    'State': 'state',
                                                    'Country': 'country',
                                                    'Zip_Code': 'zip_code'
                                                    })

df_park_locations.info()

# df_park_locations.duplicated(subset= ['park_name']).sum()

# df_park_locations.isna()
# df_park_locations.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 91 entries, 1 to 91
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   park_name  91 non-null     object
#  1   city       91 non-null     object
#  2   state      91 non-null     object
#  3   country    91 non-null     object
#  4   zip_code   91 non-null     object
# dtypes: object(5)
# memory usage: 4.3+ KB

# %% [markdown]
# ##### Wood Coasters:

# %%
df_wood_coasters.head()

# we can drop 'Location' column as we won't be needing that data as it's in other tables available that will be merged/joined
# Out:
#    Rank Year_of_Rank Award_Category          Name                       Park  \
# 0     1         2022         Wooden       Phoenix  Knoebels Amusement Resort
# 1     2         2022         Wooden        Voyage              Holiday World
# 2     3         2022         Wooden       El Toro  Six Flags Great Adventure
# 3     4         2022         Wooden  Boulder Dash             Lake Compounce
# 4     5         2022         Wooden         Beast               Kings Island
#
#                  Location              Supplier Year_Built
# 0  Elysburg, Pennsylvania       Dinn-PTC/Shmeck       1985
# 1    Santa Claus, Indiana     The Gravity Group       2006
# 2     Jackson, New Jersey               Intamin       2006
# 3    Bristol, Connecticut  Custom Coasters Int.       2000
# 4             Mason, Ohio                  KECO       1979

# %%
df_wood_coasters = df_wood_coasters.drop(columns= 'Location')
df_wood_coasters.head()
# Out:
#    Rank Year_of_Rank Award_Category          Name                       Park  \
# 0     1         2022         Wooden       Phoenix  Knoebels Amusement Resort
# 1     2         2022         Wooden        Voyage              Holiday World
# 2     3         2022         Wooden       El Toro  Six Flags Great Adventure
# 3     4         2022         Wooden  Boulder Dash             Lake Compounce
# 4     5         2022         Wooden         Beast               Kings Island
#
#                Supplier Year_Built
# 0       Dinn-PTC/Shmeck       1985
# 1     The Gravity Group       2006
# 2               Intamin       2006
# 3  Custom Coasters Int.       2000
# 4                  KECO       1979

# %%
df_wood_coasters = df_wood_coasters.rename(columns= {
                                                    'Rank': 'rank',
                                                    'Year_of_Rank': 'year_ranked',
                                                    'Award_Category': 'material_type',
                                                    'Name': 'coaster_name', # this column should be used to link with data from coaster_metrics joined w/ park_location
                                                    'Park': 'park_name',
                                                    'Supplier': 'supplier',
                                                    'Year_Built': 'year_built'
                                                    })
df_wood_coasters.info()

# there will be many duplicates in here, no need to check. and whether there are empty values, I'd rather keep the data that I do have
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 605 entries, 0 to 604
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rank           605 non-null    int64
#  1   year_ranked    605 non-null    object
#  2   material_type  605 non-null    object
#  3   coaster_name   605 non-null    object
#  4   park_name      605 non-null    object
#  5   supplier       605 non-null    object
#  6   year_built     605 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 33.2+ KB

# %% [markdown]
# ##### Steel Coasters:

# %%
df_steel_coasters.head()
# same thing as with wood coasters, we can drop 'Location' column
# Out:
#    Rank Year_of_Rank Award_Category                          Name  \
# 0     1         2022          Steel                      Fury 325
# 1     2         2022          Steel               Steel Vengeance
# 2     3         2022          Steel              Millennium Force
# 3     4         2022          Steel                    Iron Gwazi
# 4     5         2022          Steel  Jurassic World VelociCoaster
#
#                                Park                   Location  \
# 0                         Carowinds  Charlotte, North Carolina
# 1                       Cedar Point             Sandusky, Ohio
# 2                       Cedar Point             Sandusky, Ohio
# 3               Busch Gardens Tampa             Tampa, Florida
# 4  Universal's Islands of Adventure           Orlando, Florida
#
#                 Supplier Year_Built
# 0                    B&M       2015
# 1  Rocky Mountain Const.       2018
# 2                Intamin       2000
# 3  Rocky Mountain Const.       2022
# 4                Intamin       2021

# %%
df_steel_coasters = df_steel_coasters.drop(columns= 'Location')
df_steel_coasters.head()
# Out:
#    Rank Year_of_Rank Award_Category                          Name  \
# 0     1         2022          Steel                      Fury 325
# 1     2         2022          Steel               Steel Vengeance
# 2     3         2022          Steel              Millennium Force
# 3     4         2022          Steel                    Iron Gwazi
# 4     5         2022          Steel  Jurassic World VelociCoaster
#
#                                Park               Supplier Year_Built
# 0                         Carowinds                    B&M       2015
# 1                       Cedar Point  Rocky Mountain Const.       2018
# 2                       Cedar Point                Intamin       2000
# 3               Busch Gardens Tampa  Rocky Mountain Const.       2022
# 4  Universal's Islands of Adventure                Intamin       2021

# %%
df_steel_coasters = df_steel_coasters.rename(columns= {
                                                    'Rank': 'rank',
                                                    'Year_of_Rank': 'year_ranked',
                                                    'Award_Category': 'material_type',
                                                    'Name': 'coaster_name', # this column should be used to link with data from coaster_metrics joined w/ park_location
                                                    'Park': 'park_name',
                                                    'Supplier': 'supplier',
                                                    'Year_Built': 'year_built'
                                                    })
df_steel_coasters.info()

# there will be many duplicates in here, no need to check. and whether there are empty values, I'd rather keep the data that I do have
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 605 entries, 0 to 604
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rank           605 non-null    int64
#  1   year_ranked    605 non-null    object
#  2   material_type  605 non-null    object
#  3   coaster_name   605 non-null    object
#  4   park_name      605 non-null    object
#  5   supplier       605 non-null    object
#  6   year_built     605 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 33.2+ KB

# %% [markdown]
# ##### Merging/Joining Data Tables

# %%
# merging df_coaster_metrics and df_park_locations using 'park_name' column
# want to use how= 'left' because i want to keep each and every coaster_metric so i can hopefully match it with the wooden and steel coasters

df = pd.merge(df_coaster_metrics, df_park_locations, on= 'park_name', how= 'left')
# df.info()
# df.head()

result = df[df['coaster_name'] == 'Phoenix']
print(result)
# Out:
#     coaster_name            status  speed  height  length  num_inversions  \
# 140      Phoenix  status.operating   72.0    24.0   975.0             0.0
# 141      Phoenix  status.operating   65.0    15.0     NaN             0.0
#
#     material_type                   manufacturer seating_type  \
# 140        Wooden  Philadelphia Toboggan Coaster     Sit Down
# 141         Steel                         Maurer     Spinning
#
#                      park_name      city         state        country zip_code
# 140  Knoebels Amusement Resort  Elysburg  Pennsylvania  United States    17824
# 141              Adventureland       NaN           NaN            NaN      NaN

# %%
# wood coasters w/ metrics: 
# merging df with df_wood_coasters on= 'coaster_name', 'material_type', 'park_name'
# how= 'left'
# want to do a left join on df_wood_coasters because that's the data I'm primarily focused on...getting ranking & number of times ranked along with the metrics attached

df_wood = pd.merge(df_wood_coasters, df, on= ['coaster_name', 'material_type', 'park_name'], how= 'left')
df_wood.info()
df_wood.head(30)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 605 entries, 0 to 604
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   rank            605 non-null    int64
#  1   year_ranked     605 non-null    object
#  2   material_type   605 non-null    object
#  3   coaster_name    605 non-null    object
#  4   park_name       605 non-null    object
#  5   supplier        605 non-null    object
#  6   year_built      605 non-null    object
#  7   status          481 non-null    object
#  8   speed           443 non-null    float64
#  9   height          465 non-null    float64
#  10  length          472 non-null    float64
#  11  num_inversions  472 non-null    float64
#  12  manufacturer    481 non-null    object
#  13  seating_type    481 non-null    object
#  14  city            480 non-null    object
#  15  state           480 non-null    object
#  16  country         480 non-null    object
#  17  zip_code        480 non-null    object
# dtypes: float64(4), int64(1), object(13)
# memory usage: 89.8+ KB
#     rank year_ranked material_type             coaster_name  \
# 0      1        2022        Wooden                  Phoenix
# 1      2        2022        Wooden                   Voyage
# 2      3        2022        Wooden                  El Toro
# 3      4        2022        Wooden             Boulder Dash
# 4      5        2022        Wooden                    Beast
# 5      6        2022        Wooden           Mystic Timbers
# 6      7        2022        Wooden          Ravine Flyer II
# 7      8        2022        Wooden               GhostRider
# 8      9        2022        Wooden               Outlaw Run
# 9     10        2022        Wooden              Thunderhead
# 10    11        2022        Wooden             Gold Striker
# 11    12        2022        Wooden              Jack Rabbit
# 12    13        2022        Wooden                    Wodan
# 13    14        2022        Wooden          Lightning Racer
# 14    15        2022        Wooden                 Wildfire
# 15    16        2022        Wooden                     Troy
# 16    17        2022        Wooden                  Cyclone
# 17    18        2022        Wooden                   Balder
# 18    19        2022        Wooden        Shivering Timbers
# 19    20        2022        Wooden              Thunderbolt
# 20    21        2022        Wooden         Boardwalk Bullet
# 21    22        2022        Wooden                   Legend
# 22    23        2022        Wooden                    Comet
# 23    24        2022        Wooden                    Raven
# 24    25        2022        Wooden                 Colossos
# 25    26        2022        Wooden                  Goliath
# 26    27        2022        Wooden           Texas Stingray
# 27    28        2022        Wooden             Flying Turns
# 28    29        2022        Wooden  Playland Wooden Coaster
# 29    30        2022        Wooden                  Prowler
#
#                      park_name               supplier year_built  \
# 0    Knoebels Amusement Resort        Dinn-PTC/Shmeck       1985
# 1                Holiday World      The Gravity Group       2006
# 2    Six Flags Great Adventure                Intamin       2006
# 3               Lake Compounce   Custom Coasters Int.       2000
# 4                 Kings Island                   KECO       1979
# 5                 Kings Island    Great Coasters Int.       2017
# 6                    Waldameer      The Gravity Group       2008
# 7           Knott's Berry Farm   Custom Coasters/GCII       1998
# 8           Silver Dollar City  Rocky Mountain Const.       2013
# 9                    Dollywood    Great Coasters Int.       2004
# 10  California's Great America    Great Coasters Int.       2013
# 11                   Kennywood                 Miller       1920
# 12                 Europa-Park    Great Coasters Int.       2012
# 13                 Hersheypark    Great Coasters Int.       2000
# 14                   Kolmården  Rocky Mountain Const.       2016
# 15                   Toverland    Great Coasters Int.       2007
# 16                Coney Island           Baker/Keenan       1927
# 17                    Liseberg                Intamin       2003
# 18        Michigan's Adventure   Custom Coasters Int.       1998
# 19                   Kennywood          Vettel/Miller       1968
# 20             Kemah Boardwalk  The Gravity Group/M&V       2007
# 21               Holiday World   Custom Coasters Int.       2000
# 22      Six Flags Great Escape            PTC/Schmeck       1994
# 23               Holiday World   Custom Coasters Int.       1995
# 24                  Heide Park                Intamin       2001
# 25     Six Flags Great America  Rocky Mountain Const.       2014
# 26        SeaWorld San Antonio    Great Coasters Int.       2020
# 27   Knoebels Amusement Resort              Fetterman       2014
# 28                PNE Playland                  Phare       1958
# 29               Worlds of Fun    Great Coasters Int.       2009
#
#               status  speed  height  length  num_inversions  \
# 0   status.operating   72.0   24.00   975.0             0.0
# 1   status.operating  108.0   49.00  1963.0             0.0
# 2   status.operating  113.0   55.00  1341.0             0.0
# 3   status.operating   97.0   35.00  1440.0             0.0
# 4   status.operating  104.0   34.00  2243.0             0.0
# 5   status.operating   85.0   33.00   995.0             0.0
# 6                NaN    NaN     NaN     NaN             NaN
# 7   status.operating   90.0   36.00  1382.0             0.0
# 8   status.operating  110.0   50.00     NaN             2.0
# 9   status.operating   89.0   31.00   985.0             0.0
# 10  status.operating   87.0   33.00   975.0             0.0
# 11               NaN    NaN     NaN     NaN             NaN
# 12  status.operating  100.0   35.00  1050.0             0.0
# 13  status.operating   82.0   27.00  1036.0             0.0
# 14  status.operating  113.0   57.00  1300.0             3.0
# 15  status.operating   87.0   32.00  1077.0             0.0
# 16  status.operating   97.0   26.00   869.0             0.0
# 17  status.operating   90.0   36.00  1070.0             0.0
# 18               NaN    NaN     NaN     NaN             NaN
# 19               NaN    NaN     NaN     NaN             NaN
# 20  status.operating   82.0   29.00   986.0             0.0
# 21  status.operating   93.0   35.00  1232.0             0.0
# 22  status.operating   89.0   29.00  1279.0             0.0
# 23  status.operating   77.0   33.00   832.0             0.0
# 24  status.operating  110.0   51.00  1500.0             0.0
# 25  status.operating  115.0   55.00   950.0             2.0
# 26  status.operating   55.0   30.48  1029.9             0.0
# 27  status.operating   39.0   15.00   396.0             0.0
# 28  status.operating   75.0   20.00   865.0             0.0
# 29  status.operating   82.0   31.00   937.0             0.0
#
#                      manufacturer seating_type          city  \
# 0   Philadelphia Toboggan Coaster     Sit Down      Elysburg
# 1                   Gravity Group     Sit Down   Santa Claus
# 2                         Intamin     Sit Down       Jackson
# 3                             CCI     Sit Down       Bristol
# 4                    Charlie Dinn     Sit Down         Mason
# 5                             GCI     Sit Down         Mason
# 6                             NaN          NaN           NaN
# 7                             GCI     Sit Down    Buena Park
# 8                             RMC     Sit Down       Branson
# 9                             GCI     Sit Down  Pigeon Forge
# 10                            GCI     Sit Down   Santa Clara
# 11                            NaN          NaN           NaN
# 12                            GCI     Sit Down          Rust
# 13                            GCI     Sit Down       Hershey
# 14                            RMC     Sit Down     Kolmården
# 15                            GCI     Sit Down       Sevenum
# 16                             na     Sit Down      Brooklyn
# 17                        Intamin     Sit Down    Gothenburg
# 18                            NaN          NaN           NaN
# 19                            NaN          NaN           NaN
# 20                  Gravity Group     Sit Down         Kemah
# 21                            CCI     Sit Down   Santa Claus
# 22  Philadelphia Toboggan Coaster     Sit Down    Queensbury
# 23                            CCI     Sit Down   Santa Claus
# 24                        Intamin     Sit Down        Soltau
# 25                            RMC     Sit Down        Gurnee
# 26                            GCI     Sit Down   San Antonio
# 27                       Knoebels    Bobsleigh      Elysburg
# 28                             na     Sit Down     Vancouver
# 29                            GCI     Sit Down   Kansas City
#
#                 state        country zip_code
# 0        Pennsylvania  United States    17824
# 1             Indiana  United States    47579
# 2          New Jersey  United States    08527
# 3         Connecticut  United States    06010
# 4                Ohio  United States    45040
# 5                Ohio  United States    45040
# 6                 NaN            NaN      NaN
# 7          California  United States    90620
# 8            Missouri  United States    65616
# 9           Tennessee  United States    37863
# 10         California  United States    95054
# 11                NaN            NaN      NaN
# 12  Baden-Württemberg        Germany    77977
# 13       Pennsylvania  United States    17033
# 14      Östergötlands         Sweden   618 92
# 15            Limburg    Netherlands     5975
# 16           New York  United States    11224
# 17   Västra Götalands         Sweden   402 22
# 18                NaN            NaN      NaN
# 19                NaN            NaN      NaN
# 20              Texas  United States    77565
# 21            Indiana  United States    47579
# 22           New York  United States    12804
# 23            Indiana  United States    47579
# 24       Lower Saxony        Germany    29614
# 25           Illinois  United States    60031
# 26              Texas  United States    78251
# 27       Pennsylvania  United States    17824
# 28   British Columbia         Canada  V5K 5J1
# 29           Missouri  United States    64161

# %%
counts = df_wood['year_ranked'].value_counts()
# print(counts)
df_wood['year_ranked'] = df_wood['year_ranked'].replace("'14", 2014)
counts = df_wood['year_ranked'].value_counts()
# print(counts)

# %%
# steel coasters w/ metrics: 
# merging df with df_steel_coasters on= 'coaster_name', 'material_type', 'park_name'
# how= 'left'
# want to do a left join on df_steel_coasters because that's the data I'm primarily focused on...getting ranking & number of times ranked 

df_steel = pd.merge(df_steel_coasters, df, on= ['coaster_name', 'material_type', 'park_name'], how= 'left')
df_steel.info()
df_steel.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 605 entries, 0 to 604
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   rank            605 non-null    int64
#  1   year_ranked     605 non-null    object
#  2   material_type   605 non-null    object
#  3   coaster_name    605 non-null    object
#  4   park_name       605 non-null    object
#  5   supplier        605 non-null    object
#  6   year_built      605 non-null    object
#  7   status          548 non-null    object
#  8   speed           547 non-null    float64
#  9   height          544 non-null    float64
#  10  length          522 non-null    float64
#  11  num_inversions  548 non-null    float64
#  12  manufacturer    548 non-null    object
#  13  seating_type    548 non-null    object
#  14  city            548 non-null    object
#  15  state           548 non-null    object
#  16  country         548 non-null    object
#  17  zip_code        548 non-null    object
# dtypes: float64(4), int64(1), object(13)
# memory usage: 89.8+ KB
#    rank year_ranked material_type                  coaster_name  \
# 0     1        2022         Steel                      Fury 325
# 1     2        2022         Steel               Steel Vengeance
# 2     3        2022         Steel              Millennium Force
# 3     4        2022         Steel                    Iron Gwazi
# 4     5        2022         Steel  Jurassic World VelociCoaster
#
#                           park_name               supplier year_built  \
# 0                         Carowinds                    B&M       2015
# 1                       Cedar Point  Rocky Mountain Const.       2018
# 2                       Cedar Point                Intamin       2000
# 3               Busch Gardens Tampa  Rocky Mountain Const.       2022
# 4  Universal's Islands of Adventure                Intamin       2021
#
#              status  speed  height   length  num_inversions manufacturer  \
# 0  status.operating  153.0   99.00  2012.00             0.0          B&M
# 1               NaN    NaN     NaN      NaN             NaN          NaN
# 2  status.operating  150.0   94.00  2010.00             0.0      Intamin
# 3               NaN    NaN     NaN      NaN             NaN          NaN
# 4  status.operating   70.0   47.24  1432.56             4.0      Intamin
#
#   seating_type       city           state        country zip_code
# 0     Sit Down  Charlotte  North Carolina  United States    28273
# 1          NaN        NaN             NaN            NaN      NaN
# 2     Sit Down   Sandusky            Ohio  United States    44870
# 3          NaN        NaN             NaN            NaN      NaN
# 4     Sit Down    Orlando         Florida  United States    32819

# %%
counts = df_steel['year_ranked'].value_counts()
# print(counts)
df_steel['year_ranked'] = df_steel['year_ranked'].replace("'14", 2014)
counts = df_steel['year_ranked'].value_counts()
# print(counts)

# %% [markdown]
# #### Step 4: Correlation

# %%
# looks like height and speed are highly correlated on a steel coaster, no surprise, but as is speed and length and height and length, albeit less so

corr_matrix_na = df_wood.corr(method= 'pearson')
print(corr_matrix_na)
corr_matrix = df_wood.dropna().corr(method= 'pearson')
print(corr_matrix)
# Out:
#                     rank     speed    height    length  num_inversions
# rank            1.000000 -0.400285 -0.348344 -0.408077       -0.132422
# speed          -0.400285  1.000000  0.888492  0.746976        0.349603
# height         -0.348344  0.888492  1.000000  0.695831        0.436046
# length         -0.408077  0.746976  0.695831  1.000000        0.029233
# num_inversions -0.132422  0.349603  0.436046  0.029233        1.000000
#                     rank     speed    height    length  num_inversions
# rank            1.000000 -0.358153 -0.284118 -0.357358       -0.043385
# speed          -0.358153  1.000000  0.880316  0.738317        0.294290
# height         -0.284118  0.880316  1.000000  0.681914        0.383213
# length         -0.357358  0.738317  0.681914  1.000000        0.017107
# num_inversions -0.043385  0.294290  0.383213  0.017107        1.000000

# %% [markdown]
# #### Step 5: Exports

# %%
# looks like height and speed are very highly correlated on a wooden coaster...no surprise there

corr_matrix_na = df_steel.corr(method= 'pearson')
print(corr_matrix_na)
corr_matrix = df_steel.dropna().corr(method= 'pearson')
print(corr_matrix)
# Out:
#                     rank     speed    height    length  num_inversions
# rank            1.000000 -0.421471 -0.359345 -0.369333        0.249725
# speed          -0.421471  1.000000  0.925151  0.358945       -0.365896
# height         -0.359345  0.925151  1.000000  0.435823       -0.379201
# length         -0.369333  0.358945  0.435823  1.000000       -0.378001
# num_inversions  0.249725 -0.365896 -0.379201 -0.378001        1.000000
#                     rank     speed    height    length  num_inversions
# rank            1.000000 -0.413335 -0.351937 -0.366970        0.245763
# speed          -0.413335  1.000000  0.924374  0.355291       -0.366228
# height         -0.351937  0.924374  1.000000  0.434836       -0.385037
# length         -0.366970  0.355291  0.434836  1.000000       -0.381539
# num_inversions  0.245763 -0.366228 -0.385037 -0.381539        1.000000

# %%
# export to CSV file to use in Tableau

df_coaster_metrics.to_csv('coaster_metrics_final.csv', index= False)
df_park_locations.to_csv('park_locations_final.csv', index= False)
df_wood.to_csv('wood_coaster_metrics_final.csv', index= False)
df_steel.to_csv('steel_coaster_metrics_final.csv', index= False)
